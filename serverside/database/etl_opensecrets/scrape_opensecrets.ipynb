# %%
import pandas as pd
import numpy as np
import mysql.connector
import os
import time

# %%
# discover which candidates need data still
mydb = mysql.connector.connect(
        host="localhost",
        port=3308,
        user="root", 
        password="secret",
        database="ftvBackEnd"
        )
cursor = mydb.cursor()
query = """
SELECT
    cid
FROM 
    candidate
where 
    cycle = 2020 
    AND id not in  (
        SELECT candidate_id FROM `candidate-industry`
        ) 
"""
cursor.execute(query)
still_needs_data = cursor.fetchall()
print(len(still_needs_data))
mydb.close()
# Out:
# 3350

# %%
url = ("https://www.opensecrets.org/api/?method=candIndustry&cid="
       "{cid}"
       "&cycle="
       "{cycle}"
       "&apikey="
       "{apikey}"
       "&output=json"
      )
cycle=2020
apikey="wouldn't you like to know"
json_list = []
no_resource_found = []
for candidate in still_needs_data:
    open_secret_request = requests.get(url.format(cid=candidate[0], cycle=cycle, apikey=apikey))
    time.sleep(1)
    print(open_secret_request)
    if open_secret_request.ok:
        json_list.append(open_secret_request.json())
    elif open_secret_request.status_code == 404:
        no_resource_found.append(candidate)
    else:
        break
# Out:
# <Response [400]>

# %%
def insert_new_industry(code, name, cursor):
    query = """
    INSERT IGNORE INTO 
        industry(`code`, name)
    VALUES
        (%s, %s)
    """
    cursor.execute(query, (code, name))

def populate_ftv(cid, cycle, last_updated, industry_array, cursor):

    clean_cid_cycle_query = """
    DELETE FROM 
        `candidate-industry` 
    WHERE
        candidate_id = (SELECT id FROM candidate WHERE cid=%s AND cycle=%s);
    """
    insert_funding_query = """
    INSERT INTO
        `candidate-industry`(candidate_id, industry_id, indivs, pacs, total, last_updated)
    VALUES
        (
        (SELECT id FROM candidate WHERE cid=%s AND cycle=%s),
        (SELECT id FROM industry WHERE `code`=%s),
        # %s,
        # %s,
        # %s,
        # %s
        )
    """
    cursor.execute(clean_cid_cycle_query, (cid, cycle))
    if len(industry_array) == 1:
        insert_new_industry(
            industry_array["@attributes"]["industry_code"],
            industry_array["@attributes"]["industry_name"],
            cursor)
        cursor.execute(insert_funding_query, (
            cid, 
            cycle,
            industry_array["@attributes"]["industry_code"],
            industry_array["@attributes"]["indivs"],
            industry_array["@attributes"]["pacs"],
            industry_array["@attributes"]["total"],
            last_updated
        ))
    else:
        for industry in industry_array:
            
            insert_new_industry(
                industry["@attributes"]["industry_code"],
                industry["@attributes"]["industry_name"],
                cursor)
            params = (
                cid, 
                cycle,
                industry["@attributes"]["industry_code"],
                industry["@attributes"]["indivs"],
                industry["@attributes"]["pacs"],
                industry["@attributes"]["total"],
                last_updated
            )
            cursor.execute(insert_funding_query, params)


mydb = mysql.connector.connect(
    host="localhost",
    port=3308,
    user="root", 
    password="secret",
    database="ftvBackEnd"
    )
    
cursor = mydb.cursor()
for candidate in json_list:
    cid = candidate['response']['industries']['@attributes']['cid']
    cycle = candidate['response']['industries']['@attributes']['cycle']
    last_updated = candidate['response']['industries']['@attributes']['last_updated']
    industries = candidate['response']['industries']['industry']
    populate_ftv(cid, cycle, last_updated, industries, cursor)
    mydb.commit()
    
mydb.close()

# %%
json_list
# Out:
# [{'response': {'industries': {'@attributes': {'cand_name': 'Dorothy Benford (D)',
#      'cid': 'N00012192',
#      'cycle': '2020',
#      'origin': 'Center for Responsive Politics',
#      'source': 'https://www.opensecrets.org/members-of-congress/industries?cid=N00012192&cycle=2020',
#      'last_updated': '03/22/2021'},
#     'industry': [{'@attributes': {'industry_code': 'N12',
#        'industry_name': 'Misc Business',
#        'indivs': '100',
#        'pacs': '0',
#        'total': '100'}},
#      {'@attributes': {'industry_code': 'W04',
#        'industry_name': 'Education',
#        'indivs': '53',
#        'pacs': '0',
#        'total': '53'}},
#      {'@attributes': {'industry_code': 'W06',
#        'industry_name': 'Retired',
#        'indivs': '49',
#        'pacs': '0',
#        'total': '49'}},
#      {'@attributes': {'industry_code': 'F07',
#        'industry_name': 'Securities & Investment',
#        'indivs': '34',
#        'pacs': '0',
#        'total': '34'}},
#      {'@attributes': {'industry_code': 'W02',
#        'industry_name': 'Non-Profit Institutions',
#        'indivs': '25',
#        'pacs': '0',
#        'total': '25'}},
#      {'@attributes': {'industry_code': 'W05',
#        'industry_name': 'Clergy & Religious Organizations',
#        'indivs': '10',
#        'pacs': '0',
#        'total': '10'}},
#      {'@attributes': {'industry_code': 'B13',
#        'industry_name': 'Internet',
#        'indivs': '5',
#        'pacs': '0',
#        'total': '5'}},
#      {'@attributes': {'industry_code': 'B02',
#        'industry_name': 'TV/Movies/Music',
#        'indivs': '4',
#        'pacs': '0',
#        'total': '4'}},
#      {'@attributes': {'industry_code': 'K01',
#        'industry_name': 'Lawyers/Law Firms',
#        'indivs': '4',
#        'pacs': '0',
#        'total': '4'}},
#      {'@attributes': {'industry_code': 'W03',
#        'industry_name': 'Civil Servants/Public Officials',
#        'indivs': '4',
#        'pacs': '0',
#        'total': '4'}}]}}},
#  {'response': {'industries': {'@attributes': {'cand_name': 'Robert E Latta (R)',
#      'cid': 'N00012233',
#      'cycle': '2020',
#      'origin': 'Center for Responsive Politics',
#      'source': 'https://www.opensecrets.org/members-of-congress/industries?cid=N00012233&cycle=2020',
#      'last_updated': '03/22/2021'},
#     'industry': [{'@attributes': {'industry_code': 'B09',
#        'industry_name': 'Telecom Services',
#        'indivs': '14000',
#        'pacs': '85300',
#        'total': '99300'}},
#      {'@attributes': {'industry_code': 'E01',
#        'industry_name': 'Oil & Gas',
#        'indivs': '3008',
#        'pacs': '96000',
#        'total': '99008'}},
#      {'@attributes': {'industry_code': 'E08',
#        'industry_name': 'Electric Utilities',
#        'indivs': '256',
#        'pacs': '83000',
#        'total': '83256'}},
#      {'@attributes': {'industry_code': 'H01',
#        'industry_name': 'Health Professionals',
#        'indivs': '15567',
#        'pacs': '59500',
#        'total': '75067'}},
#      {'@attributes': {'industry_code': 'H04',
#        'industry_name': 'Pharmaceuticals/Health Products',
#        'indivs': '1258',
#        'pacs': '64500',
#        'total': '65758'}},
#      {'@attributes': {'industry_code': 'W06',
#        'industry_name': 'Retired',
#        'indivs': '59633',
#        'pacs': '0',
#        'total': '59633'}},
#      {'@attributes': {'industry_code': 'B08',
#        'industry_name': 'Telephone Utilities',
#        'indivs': '6103',
#        'pacs': '42500',
#        'total': '48603'}},
#      {'@attributes': {'industry_code': 'K01',
#        'industry_name': 'Lawyers/Law Firms',
#        'indivs': '33138',
#        'pacs': '13750',
#        'total': '46888'}},
#      {'@attributes': {'industry_code': 'M02',
#        'industry_name': 'Automotive',
#        'indivs': '3103',
#        'pacs': '41000',
#        'total': '44103'}},
#      {'@attributes': {'industry_code': 'F09',
#        'industry_name': 'Insurance',
#        'indivs': '13819',
#        'pacs': '30000',
#        'total': '43819'}}]}}},
#  {'response': {'industries': {'@attributes': {'cand_name': 'Betty McCollum (D)',
#      'cid': 'N00012942',
#      'cycle': '2020',
#      'origin': 'Center for Responsive Politics',
#      'source': 'https://www.opensecrets.org/members-of-congress/industries?cid=N00012942&cycle=2020',
#      'last_updated': '03/22/2021'},
#     'industry': [{'@attributes': {'industry_code': 'N07',
#        'industry_name': 'Casinos/Gambling',
#        'indivs': '109450',
#        'pacs': '2500',
#        'total': '111950'}},
#      {'@attributes': {'industry_code': 'W06',
#        'industry_name': 'Retired',
#        'indivs': '72024',
#        'pacs': '0',
#        'total': '72024'}},
#      {'@attributes': {'industry_code': 'K01',
#        'industry_name': 'Lawyers/Law Firms',
#        'indivs': '32360',
#        'pacs': '31000',
#        'total': '63360'}},
#      {'@attributes': {'industry_code': 'P04',
#        'industry_name': 'Public Sector Unions',
#        'indivs': '450',
#        'pacs': '51000',
#        'total': '51450'}},
#      {'@attributes': {'industry_code': 'F10',
#        'industry_name': 'Real Estate',
#        'indivs': '38119',
#        'pacs': '11250',
#        'total': '49369'}},
#      {'@attributes': {'industry_code': 'H01',
#        'industry_name': 'Health Professionals',
#        'indivs': '19850',
#        'pacs': '27000',
#        'total': '46850'}},
#      {'@attributes': {'industry_code': 'M01',
#        'industry_name': 'Air Transport',
#        'indivs': '1850',
#        'pacs': '41500',
#        'total': '43350'}},
#      {'@attributes': {'industry_code': 'W02',
#        'industry_name': 'Non-Profit Institutions',
#        'indivs': '27365',
#        'pacs': '12000',
#        'total': '39365'}},
#      {'@attributes': {'industry_code': 'D03',
#        'industry_name': 'Misc Defense',
#        'indivs': '10',
#        'pacs': '37500',
#        'total': '37510'}},
#      {'@attributes': {'industry_code': 'N15',
#        'industry_name': 'Misc Manufacturing & Distributing',
#        'indivs': '2766',
#        'pacs': '27500',
#        'total': '30266'}}]}}},
#  {'response': {'industries': {'@attributes': {'cand_name': 'Joyce Griggs (D)',
#      'cid': 'N00013262',
#      'cycle': '2020',
#      'origin': 'Center for Responsive Politics',
#      'source': 'https://www.opensecrets.org/members-of-congress/industries?cid=N00013262&cycle=2020',
#      'last_updated': '03/22/2021'},
#     'industry': [{'@attributes': {'industry_code': 'W04',
#        'industry_name': 'Education',
#        'indivs': '5394',
#        'pacs': '0',
#        'total': '5394'}},
#      {'@attributes': {'industry_code': 'W06',
#        'industry_name': 'Retired',
#        'indivs': '5393',
#        'pacs': '0',
#        'total': '5393'}},
#      {'@attributes': {'industry_code': 'K01',
#        'industry_name': 'Lawyers/Law Firms',
#        'indivs': '3265',
#        'pacs': '0',
#        'total': '3265'}},
#      {'@attributes': {'industry_code': 'W07',
#        'industry_name': 'Other',
#        'indivs': '2950',
#        'pacs': '0',
#        'total': '2950'}},
#      {'@attributes': {'industry_code': 'N04',
#        'industry_name': 'Misc Services',
#        'indivs': '2800',
#        'pacs': '0',
#        'total': '2800'}},
#      {'@attributes': {'industry_code': 'F03',
#        'industry_name': 'Commercial Banks',
#        'indivs': '2800',
#        'pacs': '0',
#        'total': '2800'}},
#      {'@attributes': {'industry_code': 'W03',
#        'industry_name': 'Civil Servants/Public Officials',
#        'indivs': '2465',
#        'pacs': '0',
#        'total': '2465'}},
#      {'@attributes': {'industry_code': 'B02',
#        'industry_name': 'TV/Movies/Music',
#        'indivs': '1302',
#        'pacs': '0',
#        'total': '1302'}},
#      {'@attributes': {'industry_code': 'F10',
#        'industry_name': 'Real Estate',
#        'indivs': '1180',
#        'pacs': '0',
#        'total': '1180'}},
#      {'@attributes': {'industry_code': 'H01',
#        'industry_name': 'Health Professionals',
#        'indivs': '1160',
#        'pacs': '0',
#        'total': '1160'}}]}}},
#  {'response': {'industries': {'@attributes': {'cand_name': 'Chellie Pingree (D)',
#      'cid': 'N00013817',
#      'cycle': '2020',
#      'origin': 'Center for Responsive Politics',
#      'source': 'https://www.opensecrets.org/members-of-congress/industries?cid=N00013817&cycle=2020',
#      'last_updated': '03/22/2021'},
#     'industry': [{'@attributes': {'industry_code': 'W06',
#        'industry_name': 'Retired',
#        'indivs': '50236',
#        'pacs': '0',
#        'total': '50236'}},
#      {'@attributes': {'industry_code': 'P04',
#        'industry_name': 'Public Sector Unions',
#        'indivs': '500',
#        'pacs': '24000',
#        'total': '24500'}},
#      {'@attributes': {'industry_code': 'A01',
#        'industry_name': 'Crop Production & Basic Processing',
#        'indivs': '1655',
#        'pacs': '21000',
#        'total': '22655'}},
#      {'@attributes': {'industry_code': 'P01',
#        'industry_name': 'Building Trade Unions',
#        'indivs': '0',
#        'pacs': '20000',
#        'total': '20000'}},
#      {'@attributes': {'industry_code': 'F10',
#        'industry_name': 'Real Estate',
#        'indivs': '6996',
#        'pacs': '10000',
#        'total': '16996'}},
#      {'@attributes': {'industry_code': 'H01',
#        'industry_name': 'Health Professionals',
#        'indivs': '6660',
#        'pacs': '9500',
#        'total': '16160'}},
#      {'@attributes': {'industry_code': 'Q02',
#        'industry_name': 'Democratic/Liberal',
#        'indivs': '15885',
#        'pacs': '0',
#        'total': '15885'}},
#      {'@attributes': {'industry_code': 'K01',
#        'industry_name': 'Lawyers/Law Firms',
#        'indivs': '7852',
#        'pacs': '8000',
#        'total': '15852'}},
#      {'@attributes': {'industry_code': 'P03',
#        'industry_name': 'Transportation Unions',
#        'indivs': '0',
#        'pacs': '14500',
#        'total': '14500'}},
#      {'@attributes': {'industry_code': 'N05',
#        'industry_name': 'Business Services',
#        'indivs': '13478',
#        'pacs': '0',
#        'total': '13478'}}]}}},
#  {'response': {'industries': {'@attributes': {'cand_name': 'Stephen F Lynch (D)',
#      'cid': 'N00013855',
#      'cycle': '2020',
#      'origin': 'Center for Responsive Politics',
#      'source': 'https://www.opensecrets.org/members-of-congress/industries?cid=N00013855&cycle=2020',
#      'last_updated': '03/22/2021'},
#     'industry': [{'@attributes': {'industry_code': 'F10',
#        'industry_name': 'Real Estate',
#        'indivs': '97200',
#        'pacs': '18500',
#        'total': '115700'}},
#      {'@attributes': {'industry_code': 'P04',
#        'industry_name': 'Public Sector Unions',
#        'indivs': '0',
#        'pacs': '71000',
#        'total': '71000'}},
#      {'@attributes': {'industry_code': 'F09',
#        'industry_name': 'Insurance',
#        'indivs': '1250',
#        'pacs': '62500',
#        'total': '63750'}},
#      {'@attributes': {'industry_code': 'P03',
#        'industry_name': 'Transportation Unions',
#        'indivs': '0',
#        'pacs': '52500',
#        'total': '52500'}},
#      {'@attributes': {'industry_code': 'K01',
#        'industry_name': 'Lawyers/Law Firms',
#        'indivs': '35825',
#        'pacs': '15000',
#        'total': '50825'}},
#      {'@attributes': {'industry_code': 'P01',
#        'industry_name': 'Building Trade Unions',
#        'indivs': '0',
#        'pacs': '44500',
#        'total': '44500'}},
#      {'@attributes': {'industry_code': 'F07',
#        'industry_name': 'Securities & Investment',
#        'indivs': '8600',
#        'pacs': '27000',
#        'total': '35600'}},
#      {'@attributes': {'industry_code': 'C01',
#        'industry_name': 'General Contractors',
#        'indivs': '25100',
#        'pacs': '1000',
#        'total': '26100'}},
#      {'@attributes': {'industry_code': 'P02',
#        'industry_name': 'Industrial Unions',
#        'indivs': '0',
#        'pacs': '21000',
#        'total': '21000'}},
#      {'@attributes': {'industry_code': 'C03',
#        'industry_name': 'Special Trade Contractors',
#        'indivs': '15750',
#        'pacs': '5000',
#        'total': '20750'}}]}}},
#  {'response': {'industries': {'@attributes': {'cand_name': 'Tom Kean (R)',
#      'cid': 'N00019149',
#      'cycle': '2020',
#      'origin': 'Center for Responsive Politics',
#      'source': 'https://www.opensecrets.org/members-of-congress/industries?cid=N00019149&cycle=2020',
#      'last_updated': '03/22/2021'},
#     'industry': [{'@attributes': {'industry_code': 'W06',
#        'industry_name': 'Retired',
#        'indivs': '638950',
#        'pacs': '0',
#        'total': '638950'}},
#      {'@attributes': {'industry_code': 'F10',
#        'industry_name': 'Real Estate',
#        'indivs': '253310',
#        'pacs': '12500',
#        'total': '265810'}},
#      {'@attributes': {'industry_code': 'K01',
#        'industry_name': 'Lawyers/Law Firms',
#        'indivs': '226065',
#        'pacs': '7500',
#        'total': '233565'}},
#      {'@attributes': {'industry_code': 'H01',
#        'industry_name': 'Health Professionals',
#        'indivs': '141014',
#        'pacs': '17000',
#        'total': '158014'}},
#      {'@attributes': {'industry_code': 'F07',
#        'industry_name': 'Securities & Investment',
#        'indivs': '131783',
#        'pacs': '0',
#        'total': '131783'}},
#      {'@attributes': {'industry_code': 'Q03',
#        'industry_name': 'Leadership PACs',
#        'indivs': '0',
#        'pacs': '125100',
#        'total': '125100'}},
#      {'@attributes': {'industry_code': 'Q01',
#        'industry_name': 'Republican/Conservative',
#        'indivs': '102050',
#        'pacs': '19000',
#        'total': '121050'}},
#      {'@attributes': {'industry_code': 'Q05',
#        'industry_name': 'Pro-Israel',
#        'indivs': '94057',
#        'pacs': '10610',
#        'total': '104667'}},
#      {'@attributes': {'industry_code': 'F09',
#        'industry_name': 'Insurance',
#        'indivs': '82340',
#        'pacs': '15300',
#        'total': '97640'}},
#      {'@attributes': {'industry_code': 'H04',
#        'industry_name': 'Pharmaceuticals/Health Products',
#        'indivs': '76628',
#        'pacs': '5500',
#        'total': '82128'}}]}}},
#  {'response': {'industries': {'@attributes': {'cand_name': 'James Waters (R)',
#      'cid': 'N00024194',
#      'cycle': '2020',
#      'origin': 'Center for Responsive Politics',
#      'source': 'https://www.opensecrets.org/members-of-congress/industries?cid=N00024194&cycle=2020',
#      'last_updated': '03/22/2021'},
#     'industry': [{'@attributes': {'industry_code': 'Q03',
#        'industry_name': 'Leadership PACs',
#        'indivs': '0',
#        'pacs': '5000',
#        'total': '5000'}},
#      {'@attributes': {'industry_code': 'W06',
#        'industry_name': 'Retired',
#        'indivs': '500',
#        'pacs': '0',
#        'total': '500'}}]}}},
#  {'response': {'industries': {'@attributes': {'cand_name': 'Mike D Rogers (R)',
#      'cid': 'N00024759',
#      'cycle': '2020',
#      'origin': 'Center for Responsive Politics',
#      'source': 'https://www.opensecrets.org/members-of-congress/industries?cid=N00024759&cycle=2020',
#      'last_updated': '03/22/2021'},
#     'industry': [{'@attributes': {'industry_code': 'D03',
#        'industry_name': 'Misc Defense',
#        'indivs': '58800',
#        'pacs': '81500',
#        'total': '140300'}},
#      {'@attributes': {'industry_code': 'D02',
#        'industry_name': 'Defense Electronics',
#        'indivs': '6400',
#        'pacs': '55700',
#        'total': '62100'}},
#      {'@attributes': {'industry_code': 'D01',
#        'industry_name': 'Defense Aerospace',
#        'indivs': '5600',
#        'pacs': '51000',
#        'total': '56600'}},
#      {'@attributes': {'industry_code': 'F10',
#        'industry_name': 'Real Estate',
#        'indivs': '40000',
#        'pacs': '16000',
#        'total': '56000'}},
#      {'@attributes': {'industry_code': 'A01',
#        'industry_name': 'Crop Production & Basic Processing',
#        'indivs': '1334',
#        'pacs': '51500',
#        'total': '52834'}},
#      {'@attributes': {'industry_code': 'K01',
#        'industry_name': 'Lawyers/Law Firms',
#        'indivs': '10250',
#        'pacs': '37750',
#        'total': '48000'}},
#      {'@attributes': {'industry_code': 'M01',
#        'industry_name': 'Air Transport',
#        'indivs': '4600',
#        'pacs': '41500',
#        'total': '46100'}},
#      {'@attributes': {'industry_code': 'Q03',
#        'industry_name': 'Leadership PACs',
#        'indivs': '0',
#        'pacs': '44000',
#        'total': '44000'}},
#      {'@attributes': {'industry_code': 'H01',
#        'industry_name': 'Health Professionals',
#        'indivs': '19350',
#        'pacs': '21500',
#        'total': '40850'}},
#      {'@attributes': {'industry_code': 'F09',
#        'industry_name': 'Insurance',
#        'indivs': '1000',
#        'pacs': '39600',
#        'total': '40600'}}]}}},
#  {'response': {'industries': {'@attributes': {'cand_name': 'Jeanne Shaheen (D)',
#      'cid': 'N00024790',
#      'cycle': '2020',
#      'origin': 'Center for Responsive Politics',
#      'source': 'https://www.opensecrets.org/members-of-congress/industries?cid=N00024790&cycle=2020',
#      'last_updated': '03/22/2021'},
#     'industry': [{'@attributes': {'industry_code': 'W06',
#        'industry_name': 'Retired',
#        'indivs': '3139669',
#        'pacs': '0',
#        'total': '3139669'}},
#      {'@attributes': {'industry_code': 'K01',
#        'industry_name': 'Lawyers/Law Firms',
#        'indivs': '809632',
#        'pacs': '90375',
#        'total': '900007'}},
#      {'@attributes': {'industry_code': 'F07',
#        'industry_name': 'Securities & Investment',
#        'indivs': '681347',
#        'pacs': '91000',
#        'total': '772347'}},
#      {'@attributes': {'industry_code': 'W04',
#        'industry_name': 'Education',
#        'indivs': '771389',
#        'pacs': '0',
#        'total': '771389'}},
#      {'@attributes': {'industry_code': 'Q08',
#        'industry_name': "Women's Issues",
#        'indivs': '704818',
#        'pacs': '27481',
#        'total': '732299'}},
#      {'@attributes': {'industry_code': 'Q02',
#        'industry_name': 'Democratic/Liberal',
#        'indivs': '654917',
#        'pacs': '14998',
#        'total': '669915'}},
#      {'@attributes': {'industry_code': 'F10',
#        'industry_name': 'Real Estate',
#        'indivs': '467009',
#        'pacs': '48500',
#        'total': '515509'}},
#      {'@attributes': {'industry_code': 'H01',
#        'industry_name': 'Health Professionals',
#        'indivs': '345759',
#        'pacs': '50500',
#        'total': '396259'}},
#      {'@attributes': {'industry_code': 'N05',
#        'industry_name': 'Business Services',
#        'indivs': '364208',
#        'pacs': '4800',
#        'total': '369008'}},
#      {'@attributes': {'industry_code': 'Q03',
#        'industry_name': 'Leadership PACs',
#        'indivs': '3800',
#        'pacs': '358300',
#        'total': '362100'}}]}}},
#  {'response': {'industries': {'@attributes': {'cand_name': 'Joe Wilson (R)',
#      'cid': 'N00024809',
#      'cycle': '2020',
#      'origin': 'Center for Responsive Politics',
#      'source': 'https://www.opensecrets.org/members-of-congress/industries?cid=N00024809&cycle=2020',
#      'last_updated': '03/22/2021'},
#     'industry': [{'@attributes': {'industry_code': 'W06',
#        'industry_name': 'Retired',
#        'indivs': '131776',
#        'pacs': '0',
#        'total': '131776'}},
#      {'@attributes': {'industry_code': 'Q03',
#        'industry_name': 'Leadership PACs',
#        'indivs': '0',
#        'pacs': '106800',
#        'total': '106800'}},
#      {'@attributes': {'industry_code': 'F10',
#        'industry_name': 'Real Estate',
#        'indivs': '71820',
#        'pacs': '11500',
#        'total': '83320'}},
#      {'@attributes': {'industry_code': 'K01',
#        'industry_name': 'Lawyers/Law Firms',
#        'indivs': '55628',
#        'pacs': '20500',
#        'total': '76128'}},
#      {'@attributes': {'industry_code': 'F09',
#        'industry_name': 'Insurance',
#        'indivs': '29022',
#        'pacs': '43500',
#        'total': '72522'}},
#      {'@attributes': {'industry_code': 'D03',
#        'industry_name': 'Misc Defense',
#        'indivs': '21382',
#        'pacs': '45500',
#        'total': '66882'}},
#      {'@attributes': {'industry_code': 'D01',
#        'industry_name': 'Defense Aerospace',
#        'indivs': '106',
#        'pacs': '60000',
#        'total': '60106'}},
#      {'@attributes': {'industry_code': 'Q05',
#        'industry_name': 'Pro-Israel',
#        'indivs': '40200',
#        'pacs': '14500',
#        'total': '54700'}},
#      {'@attributes': {'industry_code': 'E08',
#        'industry_name': 'Electric Utilities',
#        'indivs': '410',
#        'pacs': '48500',
#        'total': '48910'}},
#      {'@attributes': {'industry_code': 'H01',
#        'industry_name': 'Health Professionals',
#        'indivs': '25117',
#        'pacs': '19000',
#        'total': '44117'}}]}}},
#  {'response': {'industries': {'@attributes': {'cand_name': 'Doug Jones (D)',
#      'cid': 'N00024817',
#      'cycle': '2020',
#      'origin': 'Center for Responsive Politics',
#      'source': 'https://www.opensecrets.org/members-of-congress/industries?cid=N00024817&cycle=2020',
#      'last_updated': '03/22/2021'},
#     'industry': [{'@attributes': {'industry_code': 'W06',
#        'industry_name': 'Retired',
#        'indivs': '5896775',
#        'pacs': '0',
#        'total': '5896775'}},
#      {'@attributes': {'industry_code': 'K01',
#        'industry_name': 'Lawyers/Law Firms',
#        'indivs': '4607170',
#        'pacs': '149000',
#        'total': '4756170'}},
#      {'@attributes': {'industry_code': 'W04',
#        'industry_name': 'Education',
#        'indivs': '3452095',
#        'pacs': '2000',
#        'total': '3454095'}},
#      {'@attributes': {'industry_code': 'Q02',
#        'industry_name': 'Democratic/Liberal',
#        'indivs': '2266523',
#        'pacs': '36465',
#        'total': '2302988'}},
#      {'@attributes': {'industry_code': 'F07',
#        'industry_name': 'Securities & Investment',
#        'indivs': '1665945',
#        'pacs': '134300',
#        'total': '1800245'}},
#      {'@attributes': {'industry_code': 'H01',
#        'industry_name': 'Health Professionals',
#        'indivs': '1435981',
#        'pacs': '54900',
#        'total': '1490881'}},
#      {'@attributes': {'industry_code': 'F10',
#        'industry_name': 'Real Estate',
#        'indivs': '1229876',
#        'pacs': '69000',
#        'total': '1298876'}},
#      {'@attributes': {'industry_code': 'N05',
#        'industry_name': 'Business Services',
#        'indivs': '1197509',
#        'pacs': '1000',
#        'total': '1198509'}},
#      {'@attributes': {'industry_code': 'W03',
#        'industry_name': 'Civil Servants/Public Officials',
#        'indivs': '1165299',
#        'pacs': '0',
#        'total': '1165299'}},
#      {'@attributes': {'industry_code': 'B02',
#        'industry_name': 'TV/Movies/Music',
#        'indivs': '1077349',
#        'pacs': '22205',
#        'total': '1099554'}}]}}},
#  {'response': {'industries': {'@attributes': {'cand_name': 'Linda Sanchez (D)',
#      'cid': 'N00024870',
#      'cycle': '2020',
#      'origin': 'Center for Responsive Politics',
#      'source': 'https://www.opensecrets.org/members-of-congress/industries?cid=N00024870&cycle=2020',
#      'last_updated': '03/22/2021'},
#     'industry': [{'@attributes': {'industry_code': 'F09',
#        'industry_name': 'Insurance',
#        'indivs': '11642',
#        'pacs': '151500',
#        'total': '163142'}},
#      {'@attributes': {'industry_code': 'H04',
#        'industry_name': 'Pharmaceuticals/Health Products',
#        'indivs': '1500',
#        'pacs': '95500',
#        'total': '97000'}},
#      {'@attributes': {'industry_code': 'H01',
#        'industry_name': 'Health Professionals',
#        'indivs': '7411',
#        'pacs': '72000',
#        'total': '79411'}},
#      {'@attributes': {'industry_code': 'F10',
#        'industry_name': 'Real Estate',
#        'indivs': '12613',
#        'pacs': '57000',
#        'total': '69613'}},
#      {'@attributes': {'industry_code': 'F07',
#        'industry_name': 'Securities & Investment',
#        'indivs': '7670',
#        'pacs': '47500',
#        'total': '55170'}},
#      {'@attributes': {'industry_code': 'P04',
#        'industry_name': 'Public Sector Unions',
#        'indivs': '50',
#        'pacs': '51000',
#        'total': '51050'}},
#      {'@attributes': {'industry_code': 'F11',
#        'industry_name': 'Accountants',
#        'indivs': '15',
#        'pacs': '34000',
#        'total': '34015'}},
#      {'@attributes': {'industry_code': 'P01',
#        'industry_name': 'Building Trade Unions',
#        'indivs': '0',
#        'pacs': '31000',
#        'total': '31000'}},
#      {'@attributes': {'industry_code': 'P02',
#        'industry_name': 'Industrial Unions',
#        'indivs': '0',
#        'pacs': '29500',
#        'total': '29500'}},
#      {'@attributes': {'industry_code': 'W06',
#        'industry_name': 'Retired',
#        'indivs': '29290',
#        'pacs': '0',
#        'total': '29290'}}]}}},
#  {'response': {'industries': {'@attributes': {'cand_name': 'David Scott (D)',
#      'cid': 'N00024871',
#      'cycle': '2020',
#      'origin': 'Center for Responsive Politics',
#      'source': 'https://www.opensecrets.org/members-of-congress/industries?cid=N00024871&cycle=2020',
#      'last_updated': '03/22/2021'},
#     'industry': [{'@attributes': {'industry_code': 'F03',
#        'industry_name': 'Commercial Banks',
#        'indivs': '2500',
#        'pacs': '116500',
#        'total': '119000'}},
#      {'@attributes': {'industry_code': 'F10',
#        'industry_name': 'Real Estate',
#        'indivs': '75488',
#        'pacs': '42500',
#        'total': '117988'}},
#      {'@attributes': {'industry_code': 'F09',
#        'industry_name': 'Insurance',
#        'indivs': '6000',
#        'pacs': '111500',
#        'total': '117500'}},
#      {'@attributes': {'industry_code': 'F07',
#        'industry_name': 'Securities & Investment',
#        'indivs': '7000',
#        'pacs': '94500',
#        'total': '101500'}},
#      {'@attributes': {'industry_code': 'H01',
#        'industry_name': 'Health Professionals',
#        'indivs': '9500',
#        'pacs': '66500',
#        'total': '76000'}},
#      {'@attributes': {'industry_code': 'F06',
#        'industry_name': 'Finance/Credit Companies',
#        'indivs': '1500',
#        'pacs': '64500',
#        'total': '66000'}},
#      {'@attributes': {'industry_code': 'A07',
#        'industry_name': 'Agricultural Services/Products',
#        'indivs': '1500',
#        'pacs': '40500',
#        'total': '42000'}},
#      {'@attributes': {'industry_code': 'F11',
#        'industry_name': 'Accountants',
#        'indivs': '3000',
#        'pacs': '37000',
#        'total': '40000'}},
#      {'@attributes': {'industry_code': 'Q03',
#        'industry_name': 'Leadership PACs',
#        'indivs': '2500',
#        'pacs': '37500',
#        'total': '40000'}},
#      {'@attributes': {'industry_code': 'A01',
#        'industry_name': 'Crop Production & Basic Processing',
#        'indivs': '1000',
#        'pacs': '38000',
#        'total': '39000'}}]}}},
#  {'response': {'industries': {'@attributes': {'cand_name': 'Jim Oberweis (R)',
#      'cid': 'N00024894',
#      'cycle': '2020',
#      'origin': 'Center for Responsive Politics',
#      'source': 'https://www.opensecrets.org/members-of-congress/industries?cid=N00024894&cycle=2020',
#      'last_updated': '03/22/2021'},
#     'industry': [{'@attributes': {'industry_code': 'W06',
#        'industry_name': 'Retired',
#        'indivs': '223334',
#        'pacs': '0',
#        'total': '223334'}},
#      {'@attributes': {'industry_code': 'Q01',
#        'industry_name': 'Republican/Conservative',
#        'indivs': '81963',
#        'pacs': '25500',
#        'total': '107463'}},
#      {'@attributes': {'industry_code': 'Q03',
#        'industry_name': 'Leadership PACs',
#        'indivs': '0',
#        'pacs': '80000',
#        'total': '80000'}},
#      {'@attributes': {'industry_code': 'F10',
#        'industry_name': 'Real Estate',
#        'indivs': '68378',
#        'pacs': '0',
#        'total': '68378'}},
#      {'@attributes': {'industry_code': 'F07',
#        'industry_name': 'Securities & Investment',
#        'indivs': '41815',
#        'pacs': '0',
#        'total': '41815'}},
#      {'@attributes': {'industry_code': 'W04',
#        'industry_name': 'Education',
#        'indivs': '32951',
#        'pacs': '0',
#        'total': '32951'}},
#      {'@attributes': {'industry_code': 'N05',
#        'industry_name': 'Business Services',
#        'indivs': '28820',
#        'pacs': '0',
#        'total': '28820'}},
#      {'@attributes': {'industry_code': 'C01',
#        'industry_name': 'General Contractors',
#        'indivs': '25206',
#        'pacs': '3500',
#        'total': '28706'}},
#      {'@attributes': {'industry_code': 'Q16',
#        'industry_name': 'Candidate Committees',
#        'indivs': '1500',
#        'pacs': '26000',
#        'total': '27500'}},
#      {'@attributes': {'industry_code': 'K01',
#        'industry_name': 'Lawyers/Law Firms',
#        'indivs': '27131',
#        'pacs': '0',
#        'total': '27131'}}]}}},
#  {'response': {'industries': {'@attributes': {'cand_name': 'Michael R Turner (R)',
#      'cid': 'N00025175',
#      'cycle': '2020',
#      'origin': 'Center for Responsive Politics',
#      'source': 'https://www.opensecrets.org/members-of-congress/industries?cid=N00025175&cycle=2020',
#      'last_updated': '03/22/2021'},
#     'industry': [{'@attributes': {'industry_code': 'W06',
#        'industry_name': 'Retired',
#        'indivs': '121378',
#        'pacs': '0',
#        'total': '121378'}},
#      {'@attributes': {'industry_code': 'D01',
#        'industry_name': 'Defense Aerospace',
#        'indivs': '55350',
#        'pacs': '56500',
#        'total': '111850'}},
#      {'@attributes': {'industry_code': 'Q03',
#        'industry_name': 'Leadership PACs',
#        'indivs': '0',
#        'pacs': '107900',
#        'total': '107900'}},
#      {'@attributes': {'industry_code': 'F10',
#        'industry_name': 'Real Estate',
#        'indivs': '86159',
#        'pacs': '10000',
#        'total': '96159'}},
#      {'@attributes': {'industry_code': 'D03',
#        'industry_name': 'Misc Defense',
#        'indivs': '9850',
#        'pacs': '80500',
#        'total': '90350'}},
#      {'@attributes': {'industry_code': 'N15',
#        'industry_name': 'Misc Manufacturing & Distributing',
#        'indivs': '51007',
#        'pacs': '18000',
#        'total': '69007'}},
#      {'@attributes': {'industry_code': 'D02',
#        'industry_name': 'Defense Electronics',
#        'indivs': '11200',
#        'pacs': '50500',
#        'total': '61700'}},
#      {'@attributes': {'industry_code': 'K02',
#        'industry_name': 'Lobbyists',
#        'indivs': '56121',
#        'pacs': '1000',
#        'total': '57121'}},
#      {'@attributes': {'industry_code': 'F07',
#        'industry_name': 'Securities & Investment',
#        'indivs': '56003',
#        'pacs': '0',
#        'total': '56003'}},
#      {'@attributes': {'industry_code': 'H01',
#        'industry_name': 'Health Professionals',
#        'indivs': '31983',
#        'pacs': '9000',
#        'total': '40983'}}]}}},
#  {'response': {'industries': {'@attributes': {'cand_name': 'Steven A. King (R)',
#      'cid': 'N00025237',
#      'cycle': '2020',
#      'origin': 'Center for Responsive Politics',
#      'source': 'https://www.opensecrets.org/members-of-congress/industries?cid=N00025237&cycle=2020',
#      'last_updated': '03/22/2021'},
#     'industry': [{'@attributes': {'industry_code': 'W06',
#        'industry_name': 'Retired',
#        'indivs': '68882',
#        'pacs': '0',
#        'total': '68882'}},
#      {'@attributes': {'industry_code': 'A01',
#        'industry_name': 'Crop Production & Basic Processing',
#        'indivs': '15994',
#        'pacs': '0',
#        'total': '15994'}},
#      {'@attributes': {'industry_code': 'F13',
#        'industry_name': 'Misc Finance',
#        'indivs': '11860',
#        'pacs': '0',
#        'total': '11860'}},
#      {'@attributes': {'industry_code': 'Q01',
#        'industry_name': 'Republican/Conservative',
#        'indivs': '10406',
#        'pacs': '600',
#        'total': '11006'}},
#      {'@attributes': {'industry_code': 'H01',
#        'industry_name': 'Health Professionals',
#        'indivs': '10770',
#        'pacs': '0',
#        'total': '10770'}},
#      {'@attributes': {'industry_code': 'F07',
#        'industry_name': 'Securities & Investment',
#        'indivs': '10600',
#        'pacs': '0',
#        'total': '10600'}},
#      {'@attributes': {'industry_code': 'Q14',
#        'industry_name': 'Abortion Policy/Anti-Abortion',
#        'indivs': '4720',
#        'pacs': '5020',
#        'total': '9740'}},
#      {'@attributes': {'industry_code': 'K01',
#        'industry_name': 'Lawyers/Law Firms',
#        'indivs': '9000',
#        'pacs': '0',
#        'total': '9000'}},
#      {'@attributes': {'industry_code': 'N05',
#        'industry_name': 'Business Services',
#        'indivs': '8450',
#        'pacs': '0',
#        'total': '8450'}},
#      {'@attributes': {'industry_code': 'N12',
#        'industry_name': 'Misc Business',
#        'indivs': '7235',
#        'pacs': '0',
#        'total': '7235'}}]}}},
#  {'response': {'industries': {'@attributes': {'cand_name': 'Tim Ryan (D)',
#      'cid': 'N00025280',
#      'cycle': '2020',
#      'origin': 'Center for Responsive Politics',
#      'source': 'https://www.opensecrets.org/members-of-congress/industries?cid=N00025280&cycle=2020',
#      'last_updated': '03/22/2021'},
#     'industry': [{'@attributes': {'industry_code': 'W06',
#        'industry_name': 'Retired',
#        'indivs': '129748',
#        'pacs': '0',
#        'total': '129748'}},
#      {'@attributes': {'industry_code': 'K01',
#        'industry_name': 'Lawyers/Law Firms',
#        'indivs': '82774',
#        'pacs': '34000',
#        'total': '116774'}},
#      {'@attributes': {'industry_code': 'Q03',
#        'industry_name': 'Leadership PACs',
#        'indivs': '3501',
#        'pacs': '107501',
#        'total': '111002'}},
#      {'@attributes': {'industry_code': 'F10',
#        'industry_name': 'Real Estate',
#        'indivs': '79865',
#        'pacs': '16500',
#        'total': '96365'}},
#      {'@attributes': {'industry_code': 'P03',
#        'industry_name': 'Transportation Unions',
#        'indivs': '59',
#        'pacs': '70300',
#        'total': '70359'}},
#      {'@attributes': {'industry_code': 'P01',
#        'industry_name': 'Building Trade Unions',
#        'indivs': '260',
#        'pacs': '64500',
#        'total': '64760'}},
#      {'@attributes': {'industry_code': 'P04',
#        'industry_name': 'Public Sector Unions',
#        'indivs': '1305',
#        'pacs': '56000',
#        'total': '57305'}},
#      {'@attributes': {'industry_code': 'P02',
#        'industry_name': 'Industrial Unions',
#        'indivs': '773',
#        'pacs': '55000',
#        'total': '55773'}},
#      {'@attributes': {'industry_code': 'Q16',
#        'industry_name': 'Candidate Committees',
#        'indivs': '0',
#        'pacs': '45000',
#        'total': '45000'}},
#      {'@attributes': {'industry_code': 'Q09',
#        'industry_name': 'Human Rights',
#        'indivs': '34212',
#        'pacs': '7500',
#        'total': '41712'}}]}}},
#  {'response': {'industries': {'@attributes': {'cand_name': 'David Kustoff (R)',
#      'cid': 'N00025445',
#      'cycle': '2020',
#      'origin': 'Center for Responsive Politics',
#      'source': 'https://www.opensecrets.org/members-of-congress/industries?cid=N00025445&cycle=2020',
#      'last_updated': '03/22/2021'},
#     'industry': [{'@attributes': {'industry_code': 'F09',
#        'industry_name': 'Insurance',
#        'indivs': '21600',
#        'pacs': '119300',
#        'total': '140900'}},
#      {'@attributes': {'industry_code': 'F10',
#        'industry_name': 'Real Estate',
#        'indivs': '75833',
#        'pacs': '49000',
#        'total': '124833'}},
#      {'@attributes': {'industry_code': 'F03',
#        'industry_name': 'Commercial Banks',
#        'indivs': '43525',
#        'pacs': '71000',
#        'total': '114525'}},
#      {'@attributes': {'industry_code': 'F07',
#        'industry_name': 'Securities & Investment',
#        'indivs': '41900',
#        'pacs': '70000',
#        'total': '111900'}},
#      {'@attributes': {'industry_code': 'W06',
#        'industry_name': 'Retired',
#        'indivs': '95372',
#        'pacs': '0',
#        'total': '95372'}},
#      {'@attributes': {'industry_code': 'K01',
#        'industry_name': 'Lawyers/Law Firms',
#        'indivs': '76350',
#        'pacs': '6500',
#        'total': '82850'}},
#      {'@attributes': {'industry_code': 'M02',
#        'industry_name': 'Automotive',
#        'indivs': '27200',
#        'pacs': '26000',
#        'total': '53200'}},
#      {'@attributes': {'industry_code': 'Q05',
#        'industry_name': 'Pro-Israel',
#        'indivs': '41350',
#        'pacs': '11250',
#        'total': '52600'}},
#      {'@attributes': {'industry_code': 'H01',
#        'industry_name': 'Health Professionals',
#        'indivs': '22855',
#        'pacs': '16000',
#        'total': '38855'}},
#      {'@attributes': {'industry_code': 'F13',
#        'industry_name': 'Misc Finance',
#        'indivs': '28250',
#        'pacs': '9000',
#        'total': '37250'}}]}}},
#  {'response': {'industries': {'@attributes': {'cand_name': 'Dutch Ruppersberger (D)',
#      'cid': 'N00025482',
#      'cycle': '2020',
#      'origin': 'Center for Responsive Politics',
#      'source': 'https://www.opensecrets.org/members-of-congress/industries?cid=N00025482&cycle=2020',
#      'last_updated': '03/22/2021'},
#     'industry': [{'@attributes': {'industry_code': 'D03',
#        'industry_name': 'Misc Defense',
#        'indivs': '6554',
#        'pacs': '67000',
#        'total': '73554'}},
#      {'@attributes': {'industry_code': 'H01',
#        'industry_name': 'Health Professionals',
#        'indivs': '2759',
#        'pacs': '66500',
#        'total': '69259'}},
#      {'@attributes': {'industry_code': 'M01',
#        'industry_name': 'Air Transport',
#        'indivs': '595',
#        'pacs': '48000',
#        'total': '48595'}},
#      {'@attributes': {'industry_code': 'D02',
#        'industry_name': 'Defense Electronics',
#        'indivs': '2550',
#        'pacs': '45500',
#        'total': '48050'}},
#      {'@attributes': {'industry_code': 'N15',
#        'industry_name': 'Misc Manufacturing & Distributing',
#        'indivs': '705',
#        'pacs': '44000',
#        'total': '44705'}},
#      {'@attributes': {'industry_code': 'K02',
#        'industry_name': 'Lobbyists',
#        'indivs': '40980',
#        'pacs': '250',
#        'total': '41230'}},
#      {'@attributes': {'industry_code': 'D01',
#        'industry_name': 'Defense Aerospace',
#        'indivs': '10620',
#        'pacs': '30000',
#        'total': '40620'}},
#      {'@attributes': {'industry_code': 'K01',
#        'industry_name': 'Lawyers/Law Firms',
#        'indivs': '11319',
#        'pacs': '29000',
#        'total': '40319'}},
#      {'@attributes': {'industry_code': 'C04',
#        'industry_name': 'Construction Services',
#        'indivs': '1910',
#        'pacs': '36000',
#        'total': '37910'}},
#      {'@attributes': {'industry_code': 'P04',
#        'industry_name': 'Public Sector Unions',
#        'indivs': '0',
#        'pacs': '37000',
#        'total': '37000'}}]}}},
#  {'response': {'industries': {'@attributes': {'cand_name': 'Bert Oram (I)',
#      'cid': 'N00025746',
#      'cycle': '2020',
#      'origin': 'Center for Responsive Politics',
#      'source': 'https://www.opensecrets.org/members-of-congress/industries?cid=N00025746&cycle=2020',
#      'last_updated': '03/22/2021'},
#     'industry': {'@attributes': {'industry_code': 'W06',
#       'industry_name': 'Retired',
#       'indivs': '8000',
#       'pacs': '0',
#       'total': '8000'}}}}},
#  {'response': {'industries': {'@attributes': {'cand_name': 'Debbie Wasserman Schultz (D)',
#      'cid': 'N00026106',
#      'cycle': '2020',
#      'origin': 'Center for Responsive Politics',
#      'source': 'https://www.opensecrets.org/members-of-congress/industries?cid=N00026106&cycle=2020',
#      'last_updated': '03/22/2021'},
#     'industry': [{'@attributes': {'industry_code': 'W06',
#        'industry_name': 'Retired',
#        'indivs': '189376',
#        'pacs': '0',
#        'total': '189376'}},
#      {'@attributes': {'industry_code': 'K01',
#        'industry_name': 'Lawyers/Law Firms',
#        'indivs': '157296',
#        'pacs': '27500',
#        'total': '184796'}},
#      {'@attributes': {'industry_code': 'F10',
#        'industry_name': 'Real Estate',
#        'indivs': '127464',
#        'pacs': '10000',
#        'total': '137464'}},
#      {'@attributes': {'industry_code': 'P04',
#        'industry_name': 'Public Sector Unions',
#        'indivs': '115',
#        'pacs': '66500',
#        'total': '66615'}},
#      {'@attributes': {'industry_code': 'F07',
#        'industry_name': 'Securities & Investment',
#        'indivs': '58385',
#        'pacs': '6000',
#        'total': '64385'}},
#      {'@attributes': {'industry_code': 'B02',
#        'industry_name': 'TV/Movies/Music',
#        'indivs': '49786',
#        'pacs': '12500',
#        'total': '62286'}},
#      {'@attributes': {'industry_code': 'N02',
#        'industry_name': 'Beer, Wine & Liquor',
#        'indivs': '28202',
#        'pacs': '27000',
#        'total': '55202'}},
#      {'@attributes': {'industry_code': 'H01',
#        'industry_name': 'Health Professionals',
#        'indivs': '28880',
#        'pacs': '26000',
#        'total': '54880'}},
#      {'@attributes': {'industry_code': 'K02',
#        'industry_name': 'Lobbyists',
#        'indivs': '49093',
#        'pacs': '1000',
#        'total': '50093'}},
#      {'@attributes': {'industry_code': 'W04',
#        'industry_name': 'Education',
#        'indivs': '48753',
#        'pacs': '0',
#        'total': '48753'}}]}}},
#  {'response': {'industries': {'@attributes': {'cand_name': 'Cathy McMorris Rodgers (R)',
#      'cid': 'N00026314',
#      'cycle': '2020',
#      'origin': 'Center for Responsive Politics',
#      'source': 'https://www.opensecrets.org/members-of-congress/industries?cid=N00026314&cycle=2020',
#      'last_updated': '03/22/2021'},
#     'industry': [{'@attributes': {'industry_code': 'W06',
#        'industry_name': 'Retired',
#        'indivs': '494543',
#        'pacs': '0',
#        'total': '494543'}},
#      {'@attributes': {'industry_code': 'H01',
#        'industry_name': 'Health Professionals',
#        'indivs': '115654',
#        'pacs': '157000',
#        'total': '272654'}},
#      {'@attributes': {'industry_code': 'F10',
#        'industry_name': 'Real Estate',
#        'indivs': '149471',
#        'pacs': '35000',
#        'total': '184471'}},
#      {'@attributes': {'industry_code': 'H04',
#        'industry_name': 'Pharmaceuticals/Health Products',
#        'indivs': '9573',
#        'pacs': '154300',
#        'total': '163873'}},
#      {'@attributes': {'industry_code': 'E01',
#        'industry_name': 'Oil & Gas',
#        'indivs': '36004',
#        'pacs': '118500',
#        'total': '154504'}},
#      {'@attributes': {'industry_code': 'F07',
#        'industry_name': 'Securities & Investment',
#        'indivs': '107896',
#        'pacs': '26500',
#        'total': '134396'}},
#      {'@attributes': {'industry_code': 'F09',
#        'industry_name': 'Insurance',
#        'indivs': '18701',
#        'pacs': '112500',
#        'total': '131201'}},
#      {'@attributes': {'industry_code': 'B09',
#        'industry_name': 'Telecom Services',
#        'indivs': '17756',
#        'pacs': '95300',
#        'total': '113056'}},
#      {'@attributes': {'industry_code': 'Q01',
#        'industry_name': 'Republican/Conservative',
#        'indivs': '101390',
#        'pacs': '5000',
#        'total': '106390'}},
#      {'@attributes': {'industry_code': 'K02',
#        'industry_name': 'Lobbyists',
#        'indivs': '99021',
#        'pacs': '4500',
#        'total': '103521'}}]}}},
#  {'response': {'industries': {'@attributes': {'cand_name': 'Daniel Webster (R)',
#      'cid': 'N00026335',
#      'cycle': '2020',
#      'origin': 'Center for Responsive Politics',
#      'source': 'https://www.opensecrets.org/members-of-congress/industries?cid=N00026335&cycle=2020',
#      'last_updated': '03/22/2021'},
#     'industry': [{'@attributes': {'industry_code': 'W06',
#        'industry_name': 'Retired',
#        'indivs': '65942',
#        'pacs': '0',
#        'total': '65942'}},
#      {'@attributes': {'industry_code': 'F10',
#        'industry_name': 'Real Estate',
#        'indivs': '44713',
#        'pacs': '6000',
#        'total': '50713'}},
#      {'@attributes': {'industry_code': 'F09',
#        'industry_name': 'Insurance',
#        'indivs': '44025',
#        'pacs': '2500',
#        'total': '46525'}},
#      {'@attributes': {'industry_code': 'A01',
#        'industry_name': 'Crop Production & Basic Processing',
#        'indivs': '11850',
#        'pacs': '24000',
#        'total': '35850'}},
#      {'@attributes': {'industry_code': 'Q01',
#        'industry_name': 'Republican/Conservative',
#        'indivs': '25055',
#        'pacs': '1500',
#        'total': '26555'}},
#      {'@attributes': {'industry_code': 'Q03',
#        'industry_name': 'Leadership PACs',
#        'indivs': '0',
#        'pacs': '25766',
#        'total': '25766'}},
#      {'@attributes': {'industry_code': 'H01',
#        'industry_name': 'Health Professionals',
#        'indivs': '12163',
#        'pacs': '9000',
#        'total': '21163'}},
#      {'@attributes': {'industry_code': 'M04',
#        'industry_name': 'Railroads',
#        'indivs': '0',
#        'pacs': '20000',
#        'total': '20000'}},
#      {'@attributes': {'industry_code': 'W05',
#        'industry_name': 'Clergy & Religious Organizations',
#        'indivs': '13250',
#        'pacs': '0',
#        'total': '13250'}},
#      {'@attributes': {'industry_code': 'C05',
#        'industry_name': 'Building Materials & Equipment',
#        'indivs': '1000',
#        'pacs': '11500',
#        'total': '12500'}}]}}},
#  {'response': {'industries': {'@attributes': {'cand_name': 'Tim Walberg (R)',
#      'cid': 'N00026368',
#      'cycle': '2020',
#      'origin': 'Center for Responsive Politics',
#      'source': 'https://www.opensecrets.org/members-of-congress/industries?cid=N00026368&cycle=2020',
#      'last_updated': '03/22/2021'},
#     'industry': [{'@attributes': {'industry_code': 'W06',
#        'industry_name': 'Retired',
#        'indivs': '138675',
#        'pacs': '0',
#        'total': '138675'}},
#      {'@attributes': {'industry_code': 'F09',
#        'industry_name': 'Insurance',
#        'indivs': '23153',
#        'pacs': '93500',
#        'total': '116653'}},
#      {'@attributes': {'industry_code': 'F10',
#        'industry_name': 'Real Estate',
#        'indivs': '90575',
#        'pacs': '19000',
#        'total': '109575'}},
#      {'@attributes': {'industry_code': 'E08',
#        'industry_name': 'Electric Utilities',
#        'indivs': '34025',
#        'pacs': '72250',
#        'total': '106275'}},
#      {'@attributes': {'industry_code': 'F07',
#        'industry_name': 'Securities & Investment',
#        'indivs': '51409',
#        'pacs': '34500',
#        'total': '85909'}},
#      {'@attributes': {'industry_code': 'N15',
#        'industry_name': 'Misc Manufacturing & Distributing',
#        'indivs': '80189',
#        'pacs': '5500',
#        'total': '85689'}},
#      {'@attributes': {'industry_code': 'M02',
#        'industry_name': 'Automotive',
#        'indivs': '46992',
#        'pacs': '33500',
#        'total': '80492'}},
#      {'@attributes': {'industry_code': 'E01',
#        'industry_name': 'Oil & Gas',
#        'indivs': '25476',
#        'pacs': '37000',
#        'total': '62476'}},
#      {'@attributes': {'industry_code': 'Q03',
#        'industry_name': 'Leadership PACs',
#        'indivs': '0',
#        'pacs': '61500',
#        'total': '61500'}},
#      {'@attributes': {'industry_code': 'N03',
#        'industry_name': 'Retail Sales',
#        'indivs': '29975',
#        'pacs': '30804',
#        'total': '60779'}}]}}},
#  {'response': {'industries': {'@attributes': {'cand_name': 'Ro Khanna (D)',
#      'cid': 'N00026427',
#      'cycle': '2020',
#      'origin': 'Center for Responsive Politics',
#      'source': 'https://www.opensecrets.org/members-of-congress/industries?cid=N00026427&cycle=2020',
#      'last_updated': '03/22/2021'},
#     'industry': [{'@attributes': {'industry_code': 'F07',
#        'industry_name': 'Securities & Investment',
#        'indivs': '626325',
#        'pacs': '0',
#        'total': '626325'}},
#      {'@attributes': {'industry_code': 'W06',
#        'industry_name': 'Retired',
#        'indivs': '356484',
#        'pacs': '0',
#        'total': '356484'}},
#      {'@attributes': {'industry_code': 'B12',
#        'industry_name': 'Electronics Mfg & Equip',
#        'indivs': '235913',
#        'pacs': '0',
#        'total': '235913'}},
#      {'@attributes': {'industry_code': 'K01',
#        'industry_name': 'Lawyers/Law Firms',
#        'indivs': '217009',
#        'pacs': '0',
#        'total': '217009'}},
#      {'@attributes': {'industry_code': 'W04',
#        'industry_name': 'Education',
# ...
#        'total': '30800'}}]}}},
#  {'response': {'industries': {'@attributes': {'cand_name': 'Scott Perry (R)',
#      'cid': 'N00034120',
#      'cycle': '2020',
#      'origin': 'Center for Responsive Politics',
#      'source': 'https://www.opensecrets.org/members-of-congress/industries?cid=N00034120&cycle=2020',
#      'last_updated': '03/22/2021'},
#     'industry': [{'@attributes': {'industry_code': 'Q01',
#        'industry_name': 'Republican/Conservative',
#        'indivs': '797609',
#        'pacs': '61800',
#        'total': '859409'}},
#      {'@attributes': {'industry_code': 'W06',
#        'industry_name': 'Retired',
#        'indivs': '279906',
#        'pacs': '0',
#        'total': '279906'}},
#      {'@attributes': {'industry_code': 'Q03',
#        'industry_name': 'Leadership PACs',
#        'indivs': '0',
#        'pacs': '124399',
#        'total': '124399'}},
#      {'@attributes': {'industry_code': 'F10',
#        'industry_name': 'Real Estate',
#        'indivs': '90717',
#        'pacs': '21000',
#        'total': '111717'}},
#      {'@attributes': {'industry_code': 'Q16',
#        'industry_name': 'Candidate Committees',
#        'indivs': '1600',
#        'pacs': '82100',
#        'total': '83700'}},
#      {'@attributes': {'industry_code': 'F07',
#        'industry_name': 'Securities & Investment',
#        'indivs': '59314',
#        'pacs': '0',
#        'total': '59314'}},
#      {'@attributes': {'industry_code': 'K01',
#        'industry_name': 'Lawyers/Law Firms',
#        'indivs': '43306',
#        'pacs': '8250',
#        'total': '51556'}},
#      {'@attributes': {'industry_code': 'M02',
#        'industry_name': 'Automotive',
#        'indivs': '21197',
#        'pacs': '28000',
#        'total': '49197'}},
#      {'@attributes': {'industry_code': 'M01',
#        'industry_name': 'Air Transport',
#        'indivs': '3545',
#        'pacs': '42500',
#        'total': '46045'}},
#      {'@attributes': {'industry_code': 'Q13',
#        'industry_name': 'Gun Rights',
#        'indivs': '26930',
#        'pacs': '18450',
#        'total': '45380'}}]}}},
#  {'response': {'industries': {'@attributes': {'cand_name': 'Sean Patrick Maloney (D)',
#      'cid': 'N00034277',
#      'cycle': '2020',
#      'origin': 'Center for Responsive Politics',
#      'source': 'https://www.opensecrets.org/members-of-congress/industries?cid=N00034277&cycle=2020',
#      'last_updated': '03/22/2021'},
#     'industry': [{'@attributes': {'industry_code': 'W06',
#        'industry_name': 'Retired',
#        'indivs': '223664',
#        'pacs': '0',
#        'total': '223664'}},
#      {'@attributes': {'industry_code': 'F07',
#        'industry_name': 'Securities & Investment',
#        'indivs': '167508',
#        'pacs': '52000',
#        'total': '219508'}},
#      {'@attributes': {'industry_code': 'K01',
#        'industry_name': 'Lawyers/Law Firms',
#        'indivs': '182415',
#        'pacs': '18000',
#        'total': '200415'}},
#      {'@attributes': {'industry_code': 'F10',
#        'industry_name': 'Real Estate',
#        'indivs': '140532',
#        'pacs': '28500',
#        'total': '169032'}},
#      {'@attributes': {'industry_code': 'Q02',
#        'industry_name': 'Democratic/Liberal',
#        'indivs': '115735',
#        'pacs': '4000',
#        'total': '119735'}},
#      {'@attributes': {'industry_code': 'F09',
#        'industry_name': 'Insurance',
#        'indivs': '18040',
#        'pacs': '62000',
#        'total': '80040'}},
#      {'@attributes': {'industry_code': 'F13',
#        'industry_name': 'Misc Finance',
#        'indivs': '72793',
#        'pacs': '1000',
#        'total': '73793'}},
#      {'@attributes': {'industry_code': 'Q09',
#        'industry_name': 'Human Rights',
#        'indivs': '57374',
#        'pacs': '14012',
#        'total': '71386'}},
#      {'@attributes': {'industry_code': 'P03',
#        'industry_name': 'Transportation Unions',
#        'indivs': '0',
#        'pacs': '71000',
#        'total': '71000'}},
#      {'@attributes': {'industry_code': 'M05',
#        'industry_name': 'Sea Transport',
#        'indivs': '29711',
#        'pacs': '33500',
#        'total': '63211'}}]}}},
#  {'response': {'industries': {'@attributes': {'cand_name': 'Filemon Vela (D)',
#      'cid': 'N00034349',
#      'cycle': '2020',
#      'origin': 'Center for Responsive Politics',
#      'source': 'https://www.opensecrets.org/members-of-congress/industries?cid=N00034349&cycle=2020',
#      'last_updated': '03/22/2021'},
#     'industry': [{'@attributes': {'industry_code': 'A01',
#        'industry_name': 'Crop Production & Basic Processing',
#        'indivs': '6250',
#        'pacs': '84500',
#        'total': '90750'}},
#      {'@attributes': {'industry_code': 'E01',
#        'industry_name': 'Oil & Gas',
#        'indivs': '200',
#        'pacs': '58500',
#        'total': '58700'}},
#      {'@attributes': {'industry_code': 'K01',
#        'industry_name': 'Lawyers/Law Firms',
#        'indivs': '46250',
#        'pacs': '12000',
#        'total': '58250'}},
#      {'@attributes': {'industry_code': 'A07',
#        'industry_name': 'Agricultural Services/Products',
#        'indivs': '0',
#        'pacs': '52157',
#        'total': '52157'}},
#      {'@attributes': {'industry_code': 'F07',
#        'industry_name': 'Securities & Investment',
#        'indivs': '3450',
#        'pacs': '36000',
#        'total': '39450'}},
#      {'@attributes': {'industry_code': 'P01',
#        'industry_name': 'Building Trade Unions',
#        'indivs': '0',
#        'pacs': '36000',
#        'total': '36000'}},
#      {'@attributes': {'industry_code': 'F09',
#        'industry_name': 'Insurance',
#        'indivs': '4300',
#        'pacs': '25500',
#        'total': '29800'}},
#      {'@attributes': {'industry_code': 'F11',
#        'industry_name': 'Accountants',
#        'indivs': '1400',
#        'pacs': '27500',
#        'total': '28900'}},
#      {'@attributes': {'industry_code': 'D01',
#        'industry_name': 'Defense Aerospace',
#        'indivs': '0',
#        'pacs': '27500',
#        'total': '27500'}},
#      {'@attributes': {'industry_code': 'P03',
#        'industry_name': 'Transportation Unions',
#        'indivs': '0',
#        'pacs': '27000',
#        'total': '27000'}}]}}},
#  {'response': {'industries': {'@attributes': {'cand_name': 'Derek Kilmer (D)',
#      'cid': 'N00034453',
#      'cycle': '2020',
#      'origin': 'Center for Responsive Politics',
#      'source': 'https://www.opensecrets.org/members-of-congress/industries?cid=N00034453&cycle=2020',
#      'last_updated': '03/22/2021'},
#     'industry': [{'@attributes': {'industry_code': 'W06',
#        'industry_name': 'Retired',
#        'indivs': '143774',
#        'pacs': '0',
#        'total': '143774'}},
#      {'@attributes': {'industry_code': 'F09',
#        'industry_name': 'Insurance',
#        'indivs': '10795',
#        'pacs': '114000',
#        'total': '124795'}},
#      {'@attributes': {'industry_code': 'F07',
#        'industry_name': 'Securities & Investment',
#        'indivs': '70720',
#        'pacs': '49500',
#        'total': '120220'}},
#      {'@attributes': {'industry_code': 'N07',
#        'industry_name': 'Casinos/Gambling',
#        'indivs': '111984',
#        'pacs': '0',
#        'total': '111984'}},
#      {'@attributes': {'industry_code': 'H01',
#        'industry_name': 'Health Professionals',
#        'indivs': '32287',
#        'pacs': '69000',
#        'total': '101287'}},
#      {'@attributes': {'industry_code': 'F10',
#        'industry_name': 'Real Estate',
#        'indivs': '66803',
#        'pacs': '31000',
#        'total': '97803'}},
#      {'@attributes': {'industry_code': 'Q02',
#        'industry_name': 'Democratic/Liberal',
#        'indivs': '90057',
#        'pacs': '4500',
#        'total': '94557'}},
#      {'@attributes': {'industry_code': 'H04',
#        'industry_name': 'Pharmaceuticals/Health Products',
#        'indivs': '5118',
#        'pacs': '65500',
#        'total': '70618'}},
#      {'@attributes': {'industry_code': 'K01',
#        'industry_name': 'Lawyers/Law Firms',
#        'indivs': '40328',
#        'pacs': '25750',
#        'total': '66078'}},
#      {'@attributes': {'industry_code': 'B12',
#        'industry_name': 'Electronics Mfg & Equip',
#        'indivs': '22340',
#        'pacs': '43000',
#        'total': '65340'}}]}}},
#  {'response': {'industries': {'@attributes': {'cand_name': 'Grace Meng (D)',
#      'cid': 'N00034547',
#      'cycle': '2020',
#      'origin': 'Center for Responsive Politics',
#      'source': 'https://www.opensecrets.org/members-of-congress/industries?cid=N00034547&cycle=2020',
#      'last_updated': '03/22/2021'},
#     'industry': [{'@attributes': {'industry_code': 'F10',
#        'industry_name': 'Real Estate',
#        'indivs': '67947',
#        'pacs': '18500',
#        'total': '86447'}},
#      {'@attributes': {'industry_code': 'F07',
#        'industry_name': 'Securities & Investment',
#        'indivs': '55425',
#        'pacs': '23500',
#        'total': '78925'}},
#      {'@attributes': {'industry_code': 'H01',
#        'industry_name': 'Health Professionals',
#        'indivs': '41703',
#        'pacs': '13500',
#        'total': '55203'}},
#      {'@attributes': {'industry_code': 'Q09',
#        'industry_name': 'Human Rights',
#        'indivs': '27975',
#        'pacs': '27012',
#        'total': '54987'}},
#      {'@attributes': {'industry_code': 'W06',
#        'industry_name': 'Retired',
#        'indivs': '46901',
#        'pacs': '0',
#        'total': '46901'}},
#      {'@attributes': {'industry_code': 'P04',
#        'industry_name': 'Public Sector Unions',
#        'indivs': '0',
#        'pacs': '38500',
#        'total': '38500'}},
#      {'@attributes': {'industry_code': 'K01',
#        'industry_name': 'Lawyers/Law Firms',
#        'indivs': '28400',
#        'pacs': '10000',
#        'total': '38400'}},
#      {'@attributes': {'industry_code': 'Q02',
#        'industry_name': 'Democratic/Liberal',
#        'indivs': '21128',
#        'pacs': '11500',
#        'total': '32628'}},
#      {'@attributes': {'industry_code': 'F11',
#        'industry_name': 'Accountants',
#        'indivs': '6600',
#        'pacs': '24000',
#        'total': '30600'}},
#      {'@attributes': {'industry_code': 'P02',
#        'industry_name': 'Industrial Unions',
#        'indivs': '200',
#        'pacs': '25500',
#        'total': '25700'}}]}}},
#  {'response': {'industries': {'@attributes': {'cand_name': 'Donald M Payne Jr. (D)',
#      'cid': 'N00034639',
#      'cycle': '2020',
#      'origin': 'Center for Responsive Politics',
#      'source': 'https://www.opensecrets.org/members-of-congress/industries?cid=N00034639&cycle=2020',
#      'last_updated': '03/22/2021'},
#     'industry': [{'@attributes': {'industry_code': 'P01',
#        'industry_name': 'Building Trade Unions',
#        'indivs': '1000',
#        'pacs': '43800',
#        'total': '44800'}},
#      {'@attributes': {'industry_code': 'P03',
#        'industry_name': 'Transportation Unions',
#        'indivs': '1000',
#        'pacs': '42000',
#        'total': '43000'}},
#      {'@attributes': {'industry_code': 'H01',
#        'industry_name': 'Health Professionals',
#        'indivs': '11210',
#        'pacs': '28000',
#        'total': '39210'}},
#      {'@attributes': {'industry_code': 'P04',
#        'industry_name': 'Public Sector Unions',
#        'indivs': '0',
#        'pacs': '33500',
#        'total': '33500'}},
#      {'@attributes': {'industry_code': 'K02',
#        'industry_name': 'Lobbyists',
#        'indivs': '25950',
#        'pacs': '1250',
#        'total': '27200'}},
#      {'@attributes': {'industry_code': 'P05',
#        'industry_name': 'Misc Unions',
#        'indivs': '10000',
#        'pacs': '17100',
#        'total': '27100'}},
#      {'@attributes': {'industry_code': 'P02',
#        'industry_name': 'Industrial Unions',
#        'indivs': '0',
#        'pacs': '26000',
#        'total': '26000'}},
#      {'@attributes': {'industry_code': 'K01',
#        'industry_name': 'Lawyers/Law Firms',
#        'indivs': '8300',
#        'pacs': '16000',
#        'total': '24300'}},
#      {'@attributes': {'industry_code': 'M01',
#        'industry_name': 'Air Transport',
#        'indivs': '0',
#        'pacs': '24200',
#        'total': '24200'}},
#      {'@attributes': {'industry_code': 'E08',
#        'industry_name': 'Electric Utilities',
#        'indivs': '0',
#        'pacs': '22000',
#        'total': '22000'}}]}}},
#  {'response': {'industries': {'@attributes': {'cand_name': 'Stacey Plaskett (D)',
#      'cid': 'N00035000',
#      'cycle': '2020',
#      'origin': 'Center for Responsive Politics',
#      'source': 'https://www.opensecrets.org/members-of-congress/industries?cid=N00035000&cycle=2020',
#      'last_updated': '03/22/2021'},
#     'industry': [{'@attributes': {'industry_code': 'K01',
#        'industry_name': 'Lawyers/Law Firms',
#        'indivs': '23555',
#        'pacs': '14250',
#        'total': '37805'}},
#      {'@attributes': {'industry_code': 'P04',
#        'industry_name': 'Public Sector Unions',
#        'indivs': '0',
#        'pacs': '32500',
#        'total': '32500'}},
#      {'@attributes': {'industry_code': 'F07',
#        'industry_name': 'Securities & Investment',
#        'indivs': '19400',
#        'pacs': '12500',
#        'total': '31900'}},
#      {'@attributes': {'industry_code': 'P03',
#        'industry_name': 'Transportation Unions',
#        'indivs': '0',
#        'pacs': '24500',
#        'total': '24500'}},
#      {'@attributes': {'industry_code': 'A07',
#        'industry_name': 'Agricultural Services/Products',
#        'indivs': '0',
#        'pacs': '21000',
#        'total': '21000'}},
#      {'@attributes': {'industry_code': 'F13',
#        'industry_name': 'Misc Finance',
#        'indivs': '20550',
#        'pacs': '0',
#        'total': '20550'}},
#      {'@attributes': {'industry_code': 'M01',
#        'industry_name': 'Air Transport',
#        'indivs': '500',
#        'pacs': '18000',
#        'total': '18500'}},
#      {'@attributes': {'industry_code': 'N02',
#        'industry_name': 'Beer, Wine & Liquor',
#        'indivs': '0',
#        'pacs': '17340',
#        'total': '17340'}},
#      {'@attributes': {'industry_code': 'A06',
#        'industry_name': 'Livestock',
#        'indivs': '0',
#        'pacs': '15000',
#        'total': '15000'}},
#      {'@attributes': {'industry_code': 'M05',
#        'industry_name': 'Sea Transport',
#        'indivs': '10200',
#        'pacs': '4000',
#        'total': '14200'}}]}}},
#  {'response': {'industries': {'@attributes': {'cand_name': 'David P Joyce (R)',
#      'cid': 'N00035007',
#      'cycle': '2020',
#      'origin': 'Center for Responsive Politics',
#      'source': 'https://www.opensecrets.org/members-of-congress/industries?cid=N00035007&cycle=2020',
#      'last_updated': '03/22/2021'},
#     'industry': [{'@attributes': {'industry_code': 'F10',
#        'industry_name': 'Real Estate',
#        'indivs': '105403',
#        'pacs': '37500',
#        'total': '142903'}},
#      {'@attributes': {'industry_code': 'F07',
#        'industry_name': 'Securities & Investment',
#        'indivs': '107313',
#        'pacs': '24000',
#        'total': '131313'}},
#      {'@attributes': {'industry_code': 'W06',
#        'industry_name': 'Retired',
#        'indivs': '109958',
#        'pacs': '0',
#        'total': '109958'}},
#      {'@attributes': {'industry_code': 'H01',
#        'industry_name': 'Health Professionals',
#        'indivs': '28617',
#        'pacs': '69000',
#        'total': '97617'}},
#      {'@attributes': {'industry_code': 'P03',
#        'industry_name': 'Transportation Unions',
#        'indivs': '0',
#        'pacs': '85000',
#        'total': '85000'}},
#      {'@attributes': {'industry_code': 'K01',
#        'industry_name': 'Lawyers/Law Firms',
#        'indivs': '46971',
#        'pacs': '33500',
#        'total': '80471'}},
#      {'@attributes': {'industry_code': 'N15',
#        'industry_name': 'Misc Manufacturing & Distributing',
#        'indivs': '36259',
#        'pacs': '36500',
#        'total': '72759'}},
#      {'@attributes': {'industry_code': 'Q03',
#        'industry_name': 'Leadership PACs',
#        'indivs': '0',
#        'pacs': '71833',
#        'total': '71833'}},
#      {'@attributes': {'industry_code': 'Q01',
#        'industry_name': 'Republican/Conservative',
#        'indivs': '43346',
#        'pacs': '26000',
#        'total': '69346'}},
#      {'@attributes': {'industry_code': 'E01',
#        'industry_name': 'Oil & Gas',
#        'indivs': '25004',
#        'pacs': '41000',
#        'total': '66004'}}]}}}]
